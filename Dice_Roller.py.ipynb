# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from random import randint
f = plt.figure(figsize=(20, 15))
class Die():
    """A class representing a single die."""
    def __init__(self, num_sides=6):
        """Assume a six-sided die."""
        self.num_sides = num_sides
    def roll(self):
        """"Return a random value between 1 and number of sides."""
        return randint(1, self.num_sides)
# First Plot
die = Die()
# Make some rolls, and store results in a list.
results = []
for roll_num in range(1000):
    result = die.roll()
    results.append(result)
print(results)

# Analyze the results.
frequencies = []

for value in range(1, die.num_sides + 1):
    frequency = results.count(value)
    frequencies.append(frequency)

print(frequencies)

x = results
num_bins= [0.5,1.5,2.5,3.5,4.5,5.5,6.5]

plt.subplot(2, 2, 1)
n, bins, patches = plt.hist(x, num_bins, edgecolor="black" ,facecolor='blue', alpha=0.5)
plt.grid()
plt.title("Roll a dice for 1000 times")

# Second Plot
die_1 = Die()
die_2 = Die()

# Make some rolls, and store results in a list.
results = []
for roll_num in range(1000):
    result = die_1.roll() + die_2.roll()
    results.append(result)
print(results)

# Analyze the results.
frequencies = []
max_result = die_1.num_sides + die_2.num_sides
for value in range(1, max_result + 1):
    frequency = results.count(value)
    frequencies.append(frequency)

print(frequencies)

x1 = results
num_bins1= [1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5,11.5,12.5,13]

plt.subplot(2,2,2)
n, bins, patches = plt.hist(x1, num_bins1, color= 'blue', alpha=0.5)
plt.grid()
plt.title("Roll two dice for 1000 times")

# Third Plot
x = np.random.randint(100, size=(100)) 
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10* np.random.randint(100, size=(100))

plt.subplot(2,2,3)
plt.title("Scatter plot of 100 dots")
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()


plt.suptitle('Assignment 1')
plt.savefig('assignment1.png', bbox_inches = 'tight' , dpi=1200)
plt.show()
plt.close()
# Out:
# [6, 6, 2, 3, 1, 5, 4, 3, 6, 3, 1, 1, 2, 4, 4, 4, 3, 5, 4, 4, 1, 1, 2, 6, 5, 5, 6, 6, 2, 6, 3, 6, 4, 2, 4, 5, 1, 3, 4, 6, 1, 6, 6, 1, 3, 3, 4, 4, 5, 5, 1, 3, 4, 4, 3, 5, 3, 5, 5, 3, 5, 4, 6, 1, 6, 4, 3, 5, 1, 1, 6, 6, 6, 3, 3, 1, 2, 2, 6, 2, 3, 5, 1, 5, 1, 4, 5, 1, 2, 2, 4, 1, 4, 2, 1, 4, 4, 5, 3, 6, 5, 1, 6, 6, 2, 3, 1, 1, 1, 6, 5, 1, 4, 2, 3, 2, 4, 3, 3, 6, 4, 1, 1, 4, 6, 1, 6, 4, 3, 4, 2, 6, 2, 1, 5, 1, 6, 1, 6, 5, 5, 4, 6, 2, 4, 4, 6, 3, 2, 1, 2, 5, 1, 1, 4, 4, 3, 3, 6, 5, 2, 6, 5, 4, 4, 6, 6, 2, 5, 3, 6, 5, 2, 5, 4, 2, 6, 5, 5, 2, 1, 3, 4, 5, 4, 3, 5, 2, 2, 1, 4, 3, 6, 5, 3, 1, 4, 6, 1, 3, 1, 5, 5, 6, 2, 3, 3, 3, 2, 6, 2, 5, 3, 6, 1, 6, 5, 2, 4, 5, 5, 4, 6, 6, 6, 2, 2, 2, 2, 4, 6, 2, 1, 2, 6, 3, 5, 5, 3, 1, 2, 6, 2, 2, 3, 4, 6, 2, 5, 5, 4, 2, 6, 1, 2, 5, 1, 1, 4, 3, 5, 6, 5, 3, 4, 5, 5, 5, 5, 1, 5, 6, 5, 6, 2, 5, 6, 2, 6, 5, 6, 2, 5, 3, 5, 4, 4, 4, 1, 2, 3, 4, 3, 4, 6, 6, 5, 2, 4, 1, 4, 1, 1, 1, 6, 1, 2, 3, 5, 4, 4, 2, 2, 6, 5, 6, 6, 6, 4, 2, 5, 4, 5, 1, 6, 1, 5, 1, 1, 6, 4, 6, 4
# ...

# %%
#Assignment 2
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]
plt.scatter(x_values, y_values, c=(0, 0, 0.8), s=40)
# Set chart title and label axes.
# Set the range for each axis.

plt.title("Assignment 2")
plt.axis([0, 1000, 0, 1100000])

f = plt.figure(figsize=(20, 15))
plt.savefig('assignment2.png', bbox_inches = 'tight' , dpi=1200)
plt.show()
plt.close()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
